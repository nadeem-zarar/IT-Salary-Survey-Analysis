# %%
import pandas as pd

# %%
income = pd.read_csv('C:/Users/APEX COMPUTERS/Documents/Data Science/CSV Files/IT_Salary_Survey_2020_new.csv')

# %%
income.head()
# Out:
#     Age Gender    City           Position  Total years of experience  \
# 0  26.0   Male  Munich   Software Engineer                         5
# 1  26.0   Male  Berlin   Backend Developer                         7
# 2  29.0   Male  Berlin   Software Engineer                        12
# 3  28.0   Male  Berlin  Frontend Developer                         4
# 4  37.0   Male  Berlin   Backend Developer                        17
#
#   Seniority level Your main technology / programming language  \
# 0          Senior                                  TypeScript
# 1          Senior                                        Ruby
# 2            Lead                     Javascript / Typescript
# 3          Junior                                  Javascript
# 4          Senior                                     C# .NET
#
#    Yearly_salary_in_EUR Number of vacation days           Employment status  \
# 0               80000.0                      30          Full-time employee
# ...

# %%
income.columns
# Out:
# Index(['Age', 'Gender', 'City', 'Position ', 'Total years of experience',
#        'Seniority level', 'Your main technology / programming language',
#        'Yearly_salary_in_EUR', 'Number of vacation days', 'Employment status',
#        'Dontract duration', 'Main language at work', 'Company size',
#        'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
#        'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'],
#       dtype='object')

# %%
income.shape
# Out:
# (1253, 17)

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Age                                                                                                                      1226 non-null   float64
#  1   Gender                                                                                                                   1243 non-null   object
#  2   City                                                                                                                     1253 non-null   object
# ...

# %%
income.isnull().sum()
# Out:
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Seniority level                                                                                                             12
# Your main technology / programming language                                                                                127
# ...

# %%
(income.isnull().sum())/1253*100
# Out:
# Age                                                                                                                         2.154828
# Gender                                                                                                                      0.798085
# City                                                                                                                        0.000000
# Position                                                                                                                    0.478851
# Total years of experience                                                                                                   1.276935
# Seniority level                                                                                                             0.957702
# Your main technology / programming language                                                                                10.135674
# ...

# %%
income.drop(['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR',
             'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
             'Your main technology / programming language'], axis = 1,inplace = True)

# %%
income.head()
# Out:
#     Age Gender    City           Position  Total years of experience  \
# 0  26.0   Male  Munich   Software Engineer                         5
# 1  26.0   Male  Berlin   Backend Developer                         7
# 2  29.0   Male  Berlin   Software Engineer                        12
# 3  28.0   Male  Berlin  Frontend Developer                         4
# 4  37.0   Male  Berlin   Backend Developer                        17
#
#   Seniority level  Yearly_salary_in_EUR Number of vacation days  \
# 0          Senior               80000.0                      30
# 1          Senior               80000.0                      28
# 2            Lead              120000.0                      30
# 3          Junior               54000.0                      24
# 4          Senior               62000.0                      29
#
#             Employment status   Dontract duration Main language at work  \
# 0          Full-time employee  Unlimited contract               English
# ...

# %%
income.isnull().sum()
# Out:
# Age                                                        27
# Gender                                                     10
# City                                                        0
# Position                                                    6
# Total years of experience                                  16
# Seniority level                                            12
# Yearly_salary_in_EUR                                        0
# Number of vacation days                                    68
# Employment status                                          17
# Dontract duration                                          29
# Main language at work                                      16
# Company size                                               18
# Company type                                               25
# Have you lost your job due to the coronavirus outbreak?    20
# dtype: int64

# %%
median_age = income['Age'].median()
income['Age'] = income['Age'].fillna(median_age)

# %%
median_age
# Out:
# 32.0

# %%
mode_Gender = income['Gender'].mode().values[0]
income['Gender'] = income['Gender'].fillna(mode_Gender)

# %%
mode_Gender
# Out:
# 'Male'

# %%
income.dropna(axis = 0,inplace = True)

# %%
income.shape
# Out:
# (1139, 14)

# %%
income.isnull().sum()
# Out:
# Age                                                        0
# Gender                                                     0
# City                                                       0
# Position                                                   0
# Total years of experience                                  0
# Seniority level                                            0
# Yearly_salary_in_EUR                                       0
# Number of vacation days                                    0
# Employment status                                          0
# Dontract duration                                          0
# Main language at work                                      0
# Company size                                               0
# Company type                                               0
# Have you lost your job due to the coronavirus outbreak?    0
# dtype: int64

# %%
income.describe()
# Out:
#                Age  Yearly_salary_in_EUR
# count  1139.000000          1.139000e+03
# mean     32.447761          5.103720e+05
# std       5.456945          1.481314e+07
# min      20.000000          1.000100e+04
# 25%      29.000000          5.890000e+04
# 50%      32.000000          7.000000e+04
# 75%      35.000000          8.000000e+04
# max      66.000000          5.000000e+08

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1139 entries, 0 to 1252
# Data columns (total 14 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Age                                                      1139 non-null   float64
#  1   Gender                                                   1139 non-null   object
#  2   City                                                     1139 non-null   object
#  3   Position                                                 1139 non-null   object
#  4   Total years of experience                                1139 non-null   object
#  5   Seniority level                                          1139 non-null   object
#  6   Yearly_salary_in_EUR                                     1139 non-null   float64
#  7   Number of vacation days                                  1139 non-null   object
# ...

# %%
income.head()
# Out:
#     Age Gender    City           Position  Total years of experience  \
# 0  26.0   Male  Munich   Software Engineer                         5
# 1  26.0   Male  Berlin   Backend Developer                         7
# 2  29.0   Male  Berlin   Software Engineer                        12
# 3  28.0   Male  Berlin  Frontend Developer                         4
# 4  37.0   Male  Berlin   Backend Developer                        17
#
#   Seniority level  Yearly_salary_in_EUR Number of vacation days  \
# 0          Senior               80000.0                      30
# 1          Senior               80000.0                      28
# 2            Lead              120000.0                      30
# 3          Junior               54000.0                      24
# 4          Senior               62000.0                      29
#
#             Employment status   Dontract duration Main language at work  \
# 0          Full-time employee  Unlimited contract               English
# ...

# %%
income['Age']  = income['Age'].astype('int32')

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1139 entries, 0 to 1252
# Data columns (total 14 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Age                                                      1139 non-null   int32
#  1   Gender                                                   1139 non-null   object
#  2   City                                                     1139 non-null   object
#  3   Position                                                 1139 non-null   object
#  4   Total years of experience                                1139 non-null   object
#  5   Seniority level                                          1139 non-null   object
#  6   Yearly_salary_in_EUR                                     1139 non-null   float64
#  7   Number of vacation days                                  1139 non-null   object
# ...

# %%
income['Total years of experience'] = income['Total years of experience'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 income['Total years of experience'] = income['Total years of experience'].astype('float64')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
income.replace({'1,5':1.5},inplace = True)

# %%
income['Total years of experience'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 income['Total years of experience'].astype('float64')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
income['Total years of experience'].unique()
# Out:
# array(['5', '7', '12', '4', '17', '6', '8', '15', '2', '25', '14', '11',
#        '18', '30', '13', '10', '3', '40', '26', '9', '19', '20', '5.5',
#        '22', '16', '0.8', '1', '1.5', '6.5', '21', '7.5', '2.5', '28',
#        '29', '23', 1.5, '24', '0', '4.5', '27',
#        '1 (as QA Engineer) / 11 in total', '2,5', '15, thereof 8 as CTO',
#        '31', '3.5', 'less than year'], dtype=object)

# %%
income['Total years of experience'].replace({'1 (as QA Engineer) / 11 in total':11,'2,5':2.5,'15, thereof 8 as CTO':15,'less than year':12},inplace = True)

# %%
income[['Total years of experience','Yearly_salary_in_EUR']] = income[['Total years of experience','Yearly_salary_in_EUR']].astype('float64')

# %%
income.describe()
# Out:
#                Age  Total years of experience  Yearly_salary_in_EUR
# count  1139.000000                1139.000000          1.139000e+03
# mean     32.447761                   8.763477          5.103720e+05
# std       5.456945                   5.260838          1.481314e+07
# min      20.000000                   0.000000          1.000100e+04
# 25%      29.000000                   5.000000          5.890000e+04
# 50%      32.000000                   8.000000          7.000000e+04
# 75%      35.000000                  12.000000          8.000000e+04
# max      66.000000                  40.000000          5.000000e+08

# %%
import matplotlib.pyplot as plt

# %%
company_size_group = income[['Age','Company size']].groupby('Company size').Age.mean()
company_size_group
# Out:
# Company size
# 1000+       32.334928
# 101-1000    32.673854
# 51-100      33.210145
# Nov-50      31.895062
# up to 10    31.400000
# Name: Age, dtype: float64

# %%
company_size_group = pd.DataFrame(company_size_group)
company_size_group
# Out:
#                     Age
# Company size
# 1000+         32.334928
# 101-1000      32.673854
# 51-100        33.210145
# Nov-50        31.895062
# up to 10      31.400000

# %%
company_size_group.reset_index(inplace = True)

# %%
plt.bar(company_size_group['Company size'],company_size_group['Age'])
plt.show()

# %%
employ_status = income[['Age','Employment status']].groupby('Employment status').Age.median()

# %%
employ_status
# Out:
# Employment status
# Founder                                                                35.0
# Full-time employee                                                     32.0
# Part-time employee                                                     36.0
# Self-employed (freelancer)                                             32.0
# Werkstudent                                                            24.0
# Working Student                                                        24.0
# full-time, but 32 hours per week (it was my request, I'm a student)    33.0
# working student                                                        25.0
# Name: Age, dtype: float64

# %%
employ_status = pd.DataFrame(employ_status)
employ_status
# Out:
#                                                      Age
# Employment status
# Founder                                             35.0
# Full-time employee                                  32.0
# Part-time employee                                  36.0
# Self-employed (freelancer)                          32.0
# Werkstudent                                         24.0
# Working Student                                     24.0
# full-time, but 32 hours per week (it was my req...  33.0
# working student                                     25.0

# %%
employ_status.reset_index(inplace = True)

# %%
plt.bar(employ_status['Employment status'],employ_status['Age'])
plt.show()

# %%
plt.scatter(income['Age'],income['Total years of experience'])
plt.show()

# %%
plt.scatter(income['Total years of experience'],income['Yearly_salary_in_EUR'])
plt.show()

# %%
sales = pd.DataFrame({'Date':['01-05-2023','02-05-2023','03-05-2023','04-05-2023','05-05-2023'], 'Revenue':[12000,18000,35000,26000,30000]})

# %%
plt.plot(sales['Date'],sales['Revenue'])
plt.show()

# %%
plt.figure(figsize = (5,4))
plt.plot(sales['Date'],sales['Revenue'])
plt.title('Date Wise Sales')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.hist(income['Age'])
plt.show()

# %%
plt.hist(income['Total years of experience'])
plt.show()

# %%
plt.hist(income['Yearly_salary_in_EUR'])
plt.show()

# %%
income['Yearly_salary_in_EUR'].max()
# Out:
# 500000000.0

# %%
income['Yearly_salary_in_EUR'].median()
# Out:
# 70000.0

# %%
income[income['Yearly_salary_in_EUR'] == 500000000.0]
# Out:
#      Age  Gender     City    Position   Total years of experience  \
# 853   29  Female  Cologne  ML Engineer                        1.0
#
#     Seniority level  Yearly_salary_in_EUR Number of vacation days  \
# 853          Middle           500000000.0                      99
#
#       Employment status   Dontract duration Main language at work  \
# 853  Full-time employee  Unlimited contract               English
#
#     Company size Company type  \
# 853     up to 10      Startup
#
#     Have you lost your job due to the coronavirus outbreak?
# 853                                                 No

# %%
income_1 = income[income['Yearly_salary_in_EUR'] != 500000000.0]

# %%
plt.hist(income_1['Yearly_salary_in_EUR'])
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'Seniority level',data = income,palette = 'husl')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\217102203.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Seniority level',data = income,palette = 'husl')

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'Company size',data = income,palette = ['red','blue','green','purple'])
plt.xticks(rotation = 45),
plt.show()
# Out:
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\2748845625.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Company size',data = income,palette = ['red','blue','green','purple'])
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\2748845625.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x = 'Company size',data = income,palette = ['red','blue','green','purple'])

# %%
income.replace({'Nov-50':'11-50'},inplace = True)

# %%
income['Company size'].unique()
# Out:
# array(['51-100', '101-1000', '11-50', '1000+', 'up to 10'], dtype=object)

# %%
plt.figure(figsize = (8,3))
sns.countplot(x = 'Company size',data = income,palette = ['red','green','blue','purple'])
plt.xticks(rotation = 45),
plt.show()
# Out:
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\3804039831.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Company size',data = income,palette = ['red','green','blue','purple'])
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\3804039831.py:2: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x = 'Company size',data = income,palette = ['red','green','blue','purple'])

# %%
sns.displot(income['Age'], kde = True)
plt.show()

# %%
sns.kdeplot(income['Total years of experience'])
plt.show()

# %%
sns.boxplot(income['Total years of experience'])
plt.show()

# %%
income['Company size'].value_counts()
# Out:
# Company size
# 1000+       418
# 101-1000    371
# 11-50       162
# 51-100      138
# up to 10     50
# Name: count, dtype: int64

# %%
plt.pie(income['Company size'].value_counts(), labels = income['Company size'].value_counts().index)
plt.legend(loc = 'upper left')
plt.show()

# %%
income.head()
# Out:
#    Age Gender    City           Position   Total years of experience  \
# 0   26   Male  Munich   Software Engineer                        5.0
# 1   26   Male  Berlin   Backend Developer                        7.0
# 2   29   Male  Berlin   Software Engineer                       12.0
# 3   28   Male  Berlin  Frontend Developer                        4.0
# 4   37   Male  Berlin   Backend Developer                       17.0
#
#   Seniority level  Yearly_salary_in_EUR Number of vacation days  \
# 0          Senior               80000.0                      30
# 1          Senior               80000.0                      28
# 2            Lead              120000.0                      30
# 3          Junior               54000.0                      24
# 4          Senior               62000.0                      29
#
#             Employment status   Dontract duration Main language at work  \
# 0          Full-time employee  Unlimited contract               English
# ...

# %%
sns.scatterplot(x = 'Total years of experience', y = 'Age', data = income, color = 'purple')
plt.show()

# %%
plt.figure(figsize = (6,5))
sns.boxplot(x = 'Gender', y = 'Total years of experience', data = income, palette = ['blue','orange'])
plt.show()
# Out:
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\1921171078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Gender', y = 'Total years of experience', data = income, palette = ['blue','orange'])
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\1921171078.py:2: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x = 'Gender', y = 'Total years of experience', data = income, palette = ['blue','orange'])

# %%
income.corr(numeric_only = True)
# Out:
#                                 Age  Total years of experience  \
# Age                        1.000000                   0.713375
# Total years of experience  0.713375                   1.000000
# Yearly_salary_in_EUR      -0.018295                  -0.043095
#
#                            Yearly_salary_in_EUR
# Age                                   -0.018295
# Total years of experience             -0.043095
# Yearly_salary_in_EUR                   1.000000

# %%
sns.heatmap(income.corr(numeric_only = True), annot = True)
plt.show()

# %%
sns.stripplot(data = income, x = 'Company size', y = 'Total years of experience')
plt.show()

# %%
sns.scatterplot(x = 'Age', y = 'Total years of experience', hue = 'Gender', data =income)
plt.show()

# %%
sns.lmplot(data = income ,x= 'Age', y = 'Total years of experience', hue = 'Gender')
plt.show()

# %%
sns.lmplot(income, x = 'Age', y = 'Total years of experience', hue = 'Gender', row = 'Company size', fit_reg = True)
plt.show()

# %%
sns.lmplot(income, x = 'Age', y = 'Total years of experience', hue = 'Gender', col = 'Company size', fit_reg = True)
plt.show()

# %%
income.head()
# Out:
#    Age Gender    City           Position   Total years of experience  \
# 0   26   Male  Munich   Software Engineer                        5.0
# 1   26   Male  Berlin   Backend Developer                        7.0
# 2   29   Male  Berlin   Software Engineer                       12.0
# 3   28   Male  Berlin  Frontend Developer                        4.0
# 4   37   Male  Berlin   Backend Developer                       17.0
#
#   Seniority level  Yearly_salary_in_EUR Number of vacation days  \
# 0          Senior               80000.0                      30
# 1          Senior               80000.0                      28
# 2            Lead              120000.0                      30
# 3          Junior               54000.0                      24
# 4          Senior               62000.0                      29
#
#             Employment status   Dontract duration Main language at work  \
# 0          Full-time employee  Unlimited contract               English
# ...

# %%
fig, axes =  plt.subplots(2,2, figsize = (10,8))

sns.scatterplot(x = 'Total years of experience', y = 'Age', data = income, ax = axes[0,0],color = 'purple')
sns.histplot(data = income['Age'], ax = axes[0,1],color = 'green')
sns.boxplot(x = 'Company size', y = 'Age', data = income, ax = axes[1,0],palette = 'husl')
sns.barplot(x = 'Company size', y = 'Age', data = income, ax = axes[1,1],palette = ['red','green','purple','gold'])

#add titles to each subplots
axes[0,0].set_title('Scatterplot')
axes[0,1].set_title('Histplot')
axes[1,0].set_title('Boxplot')
axes[1,1].set_title('Barplot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\1509211424.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Company size', y = 'Age', data = income, ax = axes[1,0],palette = 'husl')
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\1509211424.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Company size', y = 'Age', data = income, ax = axes[1,1],palette = ['red','green','purple','gold'])
# C:\Users\APEX COMPUTERS\AppData\Local\Temp\ipykernel_8884\1509211424.py:6: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
# ...

# %%
#FacetGrid

g = sns.FacetGrid(income, col = 'Company size')
g.map(sns.scatterplot, 'Total years of experience', 'Age')
plt.show()

# %%
g = sns.FacetGrid(income, col = 'Company size', row = 'Dontract duration', height = 3, aspect = 2)
g.map(sns.scatterplot, 'Total years of experience', 'Age')
plt.show()
